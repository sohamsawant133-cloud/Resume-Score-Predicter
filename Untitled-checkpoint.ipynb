# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("dataset.csv")

X1 = df['Certificate']
X2 = df['Experience']
Y = df['Resume Score']

X = np.column_stack((X1, X2))


model = LinearRegression()
model.fit(X, Y)


x1_range = np.linspace(X1.min(), X1.max(), 10)
x2_range = np.linspace(X2.min(), X2.max(), 10)
X1_grid, X2_grid = np.meshgrid(x1_range, x2_range)

Y_pred = model.predict(np.column_stack((X1_grid.ravel(), X2_grid.ravel())))
Y_pred = Y_pred.reshape(X1_grid.shape)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X1, X2, Y, color='red', s=50, label='Actual Data')

ax.plot_surface(X1_grid, X2_grid, Y_pred, alpha=0.5)

ax.set_xlabel("Feature 1 (X1)")
ax.set_ylabel("Feature 2 (X2)")
ax.set_zlabel("Target (Y)")
ax.set_title("Multiple Linear Regression")

plt.legend()
plt.show()

# %%
# Assuming your trained model is named 'model'
print("Intercept:", model.intercept_)
print("Certificate Weight:", model.coef_[0])
print("Experience Weight:", model.coef_[1])
# Out:
# Intercept: 61.55026344915137
# Certificate Weight: 1.3455262791083822
# Experience Weight: 1.3816478011380962
